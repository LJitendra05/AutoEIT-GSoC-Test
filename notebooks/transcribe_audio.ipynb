# %%
import whisper
import pandas as pd
import os

# %%
data_folder=r'..\data\audiodata'
all_dfs=[]
for file in  os.listdir(data_folder):
    if file.endswith('.csv'):
        path=os.path.join(data_folder,file)
        df=pd.read_csv(path,encoding='utf-8')
        df=df.iloc[0:30,:3]
        df['participant']=file #mark which participant(file)
        all_dfs.append(df)
data=pd.concat(all_dfs,ignore_index=True)
data.head()
# Out:
#    Sentence                                 Stimulus  Transcription  \
# 0       1.0              Quiero cortarme el pelo (7)            NaN
# 1       2.0             El libro está en la mesa (7)            NaN
# 2       3.0              El carro lo tiene Pedro (8)            NaN
# 3       4.0              El se ducha cada mañana (9)            NaN
# 4       5.0  ¿Qué dice usted que va a hacer hoy? (9)            NaN
#
#         participant
# 0  participant1.csv
# 1  participant1.csv
# 2  participant1.csv
# 3  participant1.csv
# 4  participant1.csv

# %%
data.shape
# Out:
# (120, 4)

# %%
import re

# %%
def clean(text):
    return re.sub(r"\s*\(.*?\)","",str(text)).strip()

# %%
data['Stimulus']=data['Stimulus'].apply(clean)
data.head()
# Out:
#    Sentence                             Stimulus  Transcription  \
# 0       1.0              Quiero cortarme el pelo            NaN
# 1       2.0             El libro está en la mesa            NaN
# 2       3.0              El carro lo tiene Pedro            NaN
# 3       4.0              El se ducha cada mañana            NaN
# 4       5.0  ¿Qué dice usted que va a hacer hoy?            NaN
#
#         participant
# 0  participant1.csv
# 1  participant1.csv
# 2  participant1.csv
# 3  participant1.csv
# 4  participant1.csv

# %%
model=whisper.load_model('small')

# %%
import os
folder = r'..\data\audio'
transcriptions = []
for file in os.listdir(folder): 
    if file.endswith(".mp3"):    
        audio_path = os.path.join(folder, file)  
        print("processing",file)
        result = model.transcribe(audio_path, language="es")
        full_text = result["text"]
        sentences = re.split(r'[.!?]', full_text)
        sentences = [s.strip() for s in sentences if s.strip()]
        transcriptions.extend(sentences)
len(transcriptions)
# Out:
# processing participant1.mp3
# processing participant2.mp3
# processing participant3.mp3
# processing participant4.mp3
# 116

# %%
data["Transcription"].iloc[:len(transcriptions)] = transcriptions
data.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6804\1683590571.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Transcription"].iloc[:len(transcriptions)] = transcriptions
#    Sentence                             Stimulus             Transcription  \
# 0       1.0              Quiero cortarme el pelo   Quiero cortarme el pelo
# 1       2.0             El libro está en la mesa   Quiero cortarme el pelo
# 2       3.0              El carro lo tiene Pedro  El libro está en la mesa
# 3       4.0              El se ducha cada mañana  El libro está en la mesa
# 4       5.0  ¿Qué dice usted que va a hacer hoy?  El caro lo tiene el pelo
#
#         participant
# 0  participant1.csv
# 1  participant1.csv
# 2  participant1.csv
# 3  participant1.csv
# 4  participant1.csv

# %%
data.to_csv("../results/participant_transcription.csv", index=False)
